# %% [markdown]
# #### Core Understanding

# %% [markdown]
# - Supply Chain = Flow of goods from supplier → warehouse → customer

# %% [markdown]
# #### End-to-End Flow

# %% [markdown]
# Supplier → Manufacturer → Warehouse → Distribution → Customer

# %% [markdown]
# ___

# %% [markdown]
# - Key Insight
#   -  Unlike e-commerce (front-end sales):
#   - Supply chain is back-end operations
