# %% [markdown]
# ##### Supply chain is event + transaction driven

# %% [markdown]
# ___

# %% [markdown]
# - Core Events
#   -  Order Events
#      - order_created
#      - order_shipped
#      - order_delivered

# %% [markdown]
# - Inventory Events
#   - stock_added
#   - stock_removed
#   - stock_updated
# - Logistics Events
#   - shipment_started
#   - in_transit
#   - delivered

# %% [markdown]
# ___

# %% [markdown]
# - Derived Features
#   - Demand per day
#   - Lead time per supplier
#   - Stockout frequency
