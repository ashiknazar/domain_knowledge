# %% [markdown]
# #### ML / AI Use Cases

# %% [markdown]
# ___

# %% [markdown]
# - 1.Demand Forecasting
#   - Predict future demand

# %% [markdown]
# - 2.Inventory Optimization
#   - Decide how much stock to keep

# %% [markdown]
# - 3.Route Optimization
#   - Find best delivery routes

# %% [markdown]
# - 4.Delay Prediction
#   - Predict late deliveries

# %% [markdown]
# - 5.Supplier Risk Analysis
#   - Identify unreliable suppliers

# %% [markdown]
# ____

# %% [markdown]
# ##### Important Concepts

# %% [markdown]
# - Reorder Point
#   - When to restock
#   - Reorder Point = Demand during lead time + Safety stock

# %% [markdown]
# - Safety Stock
#     - Extra stock to handle uncertainty

# %% [markdown]
# - Bullwhip Effect
#    - Small demand change → large upstream impact
