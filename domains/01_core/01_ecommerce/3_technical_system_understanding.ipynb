# %% [markdown]
# ### Technical / System Understanding

# %% [markdown]
# Typical Pipeline

# %% [markdown]
# ```tree
# Frontend / App
#    ↓
# Event Tracking (clicks, actions)
#    ↓
# Kafka (stream ingestion)
#    ↓
# Spark (real-time processing)
#    ↓
# Storage (HDFS / Data Warehouse)
#    ↓
# Dashboard / ML Models

# %% [markdown]
# ___
# #### What processing happens?
# - Funnel analysis
# - Real-time sales tracking
# - Recommendation systems
# - Fraud detection
