# %% [markdown]
# ##### Common Events

# %% [markdown]
# - page_view
# - product_view
# - add_to_cart
# - remove_from_cart
# - checkout_started
# - payment_success

# %% [markdown]
# ___

# %% [markdown]
# - Example data record

# %% [markdown]
# ```json
# {
#   "user_id": "U123",
#   "product_id": "P456",
#   "event": "add_to_cart",
#   "timestamp": "2026-04-08T10:30:00",
#   "price": 499,
#   "category": "electronics"
# }
# ```
