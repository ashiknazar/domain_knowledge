# %% [markdown]
# - “How do you calculate conversion rate?”
#
#   - “By dividing the number of purchase events by total unique users or sessions.”

# %% [markdown]
# ___
# - “Where does data come from?”
#
#    - “From user interactions like clicks, views, and transactions captured as events.”

# %% [markdown]
# ___

# %% [markdown]
# - “What challenges exist?”
#
#   - Data skew (popular products)
#   - Real-time processing requirements
#   - Incomplete user journeys

# %% [markdown]
# ___
# - Final mental model (remember this)
#
#    - E-commerce = Funnel + Events + KPIs
