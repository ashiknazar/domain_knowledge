# %% [markdown]
# #### ML / AI Use Cases

# %% [markdown]
# - Recommendation Systems
#
#    - “People who bought X also bought Y”

# %% [markdown]
# - Churn Prediction
#   - Predict which users may leave

# %% [markdown]
# - Dynamic Pricing
#   - Adjust price based on demand

# %% [markdown]
# - Search Ranking
#   - Show most relevant products first

# %% [markdown]
# ___
