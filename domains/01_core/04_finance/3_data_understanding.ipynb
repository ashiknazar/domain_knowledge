# %% [markdown]
# #### Everything is transaction-driven

# %% [markdown]
# ___

# %% [markdown]
# #### Core Events

# %% [markdown]
# - transaction_initiated
# - transaction_completed
# - transaction_failed
# - login_attempt
# - account_update

# %% [markdown]
# ___

# %% [markdown]
# #### Example Transaction Data
# ```json
# {
#   "transaction_id": "T123",
#   "user_id": "U456",
#   "amount": 10000,
#   "timestamp": "2026-04-10T09:00:00",
#   "location": "India",
#   "device": "mobile",
#   "merchant": "Amazon",
#   "status": "success"
# }
# ```

# %% [markdown]
# ___

# %% [markdown]
# #### Important Features (used in ML)

# %% [markdown]
# These are what make finance interesting:
#
# - Transaction amount
# - Frequency of transactions
# - Location change
# - Device change
# - Time of transaction (midnight activity )

# %% [markdown]
# ____

# %% [markdown]
# - Example Fraud Pattern
#    - User normally spends ₹500
#    - Suddenly spends ₹50,000 in another country
