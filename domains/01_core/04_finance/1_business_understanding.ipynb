# %% [markdown]
# #### What is the goal?
# - Manage money, minimize risk, detect fraud, and maximize returns.

# %% [markdown]
# ___

# %% [markdown]
# #### Core Areas in Finance

# %% [markdown]
# - Transactions
#    - Payments, transfers, purchases

# %% [markdown]
# - Risk Management
#    - Will this customer default?

# %% [markdown]
# - Fraud Detection ⭐ (MOST IMPORTANT)
#    - Is this transaction suspicious?
