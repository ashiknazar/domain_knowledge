# %% [markdown]
# - Genetics = study of genes, DNA, and heredity

# %% [markdown]
# ___

# %% [markdown]
# #### DNA (Deoxyribonucleic Acid)

# %% [markdown]
# - The molecule that stores genetic information

# %% [markdown]
# #### Gene
#
# - A segment of DNA that codes for a function/protein

# %% [markdown]
# #### Genome
#
# - Entire DNA of an organism

# %% [markdown]
# #### Mutation
#    - Change in DNA sequence

# %% [markdown]
# #### Variant
# - Difference in DNA between individuals
