# %% [markdown]
# - Goal in genetics:
#   - Understand how genes affect disease and personalize treatment

# %% [markdown]
# ___
#
# #### Applications

# %% [markdown]
# - Disease Identification
#    - Find genetic cause of diseases

# %% [markdown]
# - Personalized Medicine
#    - Tailor treatment based on DNA

# %% [markdown]
# - Drug Discovery
#   - Identify new drug targets

# %% [markdown]
# - Ancestry Analysis
#   - Trace lineage
