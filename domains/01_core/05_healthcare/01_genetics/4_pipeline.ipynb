# %% [markdown]
# ```tree
# DNA Sequencing Machine
#    ↓
# Raw Sequence Data
#    ↓
# Alignment (map to reference genome)
#    ↓
# Variant Calling (find mutations)
#    ↓
# VCF Files
#    ↓
# Feature Engineering
#    ↓
# ML Models (disease prediction)

# %% [markdown]
# ___

# %% [markdown]
# - Alignment
#    -  Compare DNA with reference genome
