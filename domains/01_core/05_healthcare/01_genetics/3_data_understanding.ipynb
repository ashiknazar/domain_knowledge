# %% [markdown]
# - Genetics data is VERY different from normal tabular data

# %% [markdown]
# ___

# %% [markdown]
# #### Types of Data

# %% [markdown]
# - DNA Sequence Data

# %% [markdown]
# - Variant Data (MOST USED)
#    - Stored as:
#    - SNPs (Single Nucleotide Polymorphisms)

# %% [markdown]
# - SNP (Single Nucleotide Polymorphism)
#   - Change in one DNA letter

# %% [markdown]
# | Position | Normal | Variant |
# | -------- | ------ | ------- |
# | 1001     | A      | G       |

# %% [markdown]
# - VCF File (VERY IMPORTANT)
#   -  Standard format:
#      - Stores genetic variants
