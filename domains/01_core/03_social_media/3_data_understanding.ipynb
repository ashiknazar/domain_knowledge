# %% [markdown]
# - Everything is user-generated + interaction-heavy

# %% [markdown]
# #### Core Events

# %% [markdown]
# - Content Creation Events:
#   - post_created
#   - story_uploaded
#   - reel_uploaded

# %% [markdown]
# - Interaction Events:
#   - like
#   - comment
#   - share
#   - follow
#   - unfollow
#
# - Consumption Events:
#   - feed_view
#   - post_view
#   - scroll

# %% [markdown]
# - Derived Metrics
#   - Engagement per post
#   - User activity frequency
#   - Follower graph growth
