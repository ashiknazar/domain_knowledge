# %% [markdown]
# #### Core KPIs

# %% [markdown]
# ___

# %% [markdown]
# -  Engagement Rate
#    - (likes + comments + shares) / impressions

# %% [markdown]
# - DAU / MAU
#    - Daily Active Users / Monthly Active Users

# %% [markdown]
# - Session Duration
#    - Time spent per session

# %% [markdown]
# - Retention Rate
#   - % of users coming back after X days

# %% [markdown]
# - Follower Growth
#   - How fast users gain connections

# %% [markdown]
# - Impressions
#   - Number of times content is shown
