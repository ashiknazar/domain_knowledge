# %% [markdown]
# - Goal is NOT just content consumption (like media)
#    - It is user interaction + network growth + retention

# %% [markdown]
# ___

# %% [markdown]
# - Core Objectives
#   - Increase user engagement
#   - Grow network (followers/friends)
#   - Maximize time spent
#   - Keep users coming back (retention)

# %% [markdown]
# ___
