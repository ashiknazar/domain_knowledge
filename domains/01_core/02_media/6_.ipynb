# %% [markdown]
# - “How do you detect trending topics?”
#    - Count article views over time
#    - Detect sudden spikes
#    - Compare current vs historical activity

# %% [markdown]
# - “What data is important?”
#    - Article metadata (category, timestamp)
#    - User interactions (views, clicks, shares)

# %% [markdown]
# - “Challenges?”
#   - High volume of data
#   - Noise (clickbait, bots)
#   - Real-time processing
