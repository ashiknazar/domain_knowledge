# %% [markdown]
# ##### Everything is content + user interaction driven

# %% [markdown]
# ____

# %% [markdown]
# - Core Events
#    - article_published
#    - article_updated
# - User Events:
#    - article_view
#    - like
#    - share
#    - comment
#    - scroll

# %% [markdown]
# ____
# - Example data

# %% [markdown]
# ```json
# {
#   "user_id": "U123",
#   "article_id": "A456",
#   "event": "article_view",
#   "timestamp": "2026-04-10T09:00:00",
#   "category": "politics",
#   "device": "mobile"
# }

# %% [markdown]
# - Important Derived Metrics
#   - Views per article
#   - Average read time
#   - Engagement per category
