# %% [markdown]
# #### Core KPIs

# %% [markdown]
# - Page Views
#    - Page Views
# - Unique Users
#    - Number of distinct users
# - Time Spent
#    - How long users read content
# - Engagement Rate
#    - Likes, shares, comments
# - Trending Score
#    - How fast a topic is gaining popularity
# - Sentiment Score
#   - Positive / Negative tone of news

# %% [markdown]
# ___

# %% [markdown]
# #### Important Insight
# - Unlike finance:
#   - No direct money loss
#   - Focus is on attention + engagement
