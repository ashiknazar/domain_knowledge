# %% [markdown]
# ### ML / AI Use Cases

# %% [markdown]
# ___

# %% [markdown]
# #### 1. Trending Topic Detection
# - Identify what’s becoming popular NOW

# %% [markdown]
# #### 2. Sentiment Analysis
#
# - Classify news as positive / negative / neutral

# %% [markdown]
# #### 3. Recommendation Systems
# - Show personalized articles

# %% [markdown]
# #### 4. Content Classification
# - Categorize articles (sports, politics, etc.)

# %% [markdown]
# #### 5. Fake News Detection (advanced)
# - Identify unreliable content

# %% [markdown]
# ___
#
# > “In the media domain, the goal is to maximize user engagement by delivering relevant content. We track user interactions like article views, shares, and reading time to compute metrics such as engagement rate and trending topics. These events are processed using streaming systems to detect real-time trends and power recommendation systems.”
