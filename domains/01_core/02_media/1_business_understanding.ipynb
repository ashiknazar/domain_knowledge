# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ___

# %% [markdown]
# - What is the goal?
#   - Deliver relevant content to users and maximize engagement.

# %% [markdown]
# -  Key Objectives
#    - Show interesting news
#    - Keep users engaged
#    - Increase time spent
#    - Identify trending topics
